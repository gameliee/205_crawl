# %%
import marshal

with open('itviec/all_2023-02-21T09-57-45.marshal', 'rb') as f:
    all = marshal.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 import marshal
#       3 with open('itviec/all_2023-02-21T09-57-45.marshal', 'rb') as f:
# ----> 4     all = marshal.load(f)
#
# EOFError: EOF read where object expected

# %%
all['html_raw']
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\' xml:lang=\'en\' xmlns=\'http://www.w3.org/1999/xhtml\'>\n<head>\n<meta content=\'en\' http-equiv=\'content-language\'>\n<meta charset=\'utf-8\'>\n<meta content=\'width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no\' name=\'viewport\'>\n<title>Product Design Leader at HDBank | ITviec</title>\n<meta content=\'HDBank is hiring Product Design Leader at Ho Chi Minh. High salary, good benefit job.\' name=\'description\'>\n<meta content=\'unavailable_after: 21-Mar-2023 15:34:47 +0700\' name=\'GOOGLEBOT\'>\n<meta content=\'HDBank is hiring Product Design Leader at Ho Chi Minh. High salary, good benefit job.\' property=\'og:description\'>\n<meta content=\'Product Design Leader at HDBank | ITviec\' property=\'og:title\'>\n\n<script>\n  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\
# ...
